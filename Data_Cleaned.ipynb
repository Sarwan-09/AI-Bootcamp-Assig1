# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
# 891          NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      1
# Survived         1
# Pclass           1
# Name             1
# Sex              1
# Age            177
# SibSp            1
# Parch            1
# Ticket           1
# Fare             1
# Cabin          688
# Embarked         3
# dtype: int64

# %% [markdown]
# #### Deleting Unnecessary Column

# %%
df =df.drop("Cabin", axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
# 891          NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Here we delete unnecessary columns like passenger id, names and Tickets.

# %%
df = df.drop(["PassengerId", "Name" , "Ticket" ], axis=1)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0     3.0    male  22.0    1.0    0.0   7.2500        S
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833        C
# 2         1.0     3.0  female  26.0    0.0    0.0   7.9250        S
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S
# 4         0.0     3.0    male  35.0    0.0    0.0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S
# 888       0.0     3.0  female   NaN    1.0    2.0  23.4500        S
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q
# 891       NaN     NaN     NaN  28.0    NaN    NaN      NaN      NaN
#
# [892 rows x 8 columns]

# %% [markdown]
# #### Checking for nulls

# %%
df.isnull().sum()
# Out:
# Survived      1
# Pclass        1
# Sex           1
# Age         177
# SibSp         1
# Parch         1
# Fare          1
# Embarked      3
# dtype: int64

# %%
plt.scatter(df['Age'], df['Survived'])

# %% [markdown]
# ### Filling the age with median value

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df.isnull().sum()
# Out:
# Survived    1
# Pclass      1
# Sex         1
# Age         0
# SibSp       1
# Parch       1
# Fare        1
# Embarked    3
# dtype: int64

# %% [markdown]
# #### Filling Embarked with most repeated value

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0     3.0    male  22.0    1.0    0.0   7.2500        S
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833        C
# 2         1.0     3.0  female  26.0    0.0    0.0   7.9250        S
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S
# 4         0.0     3.0    male  35.0    0.0    0.0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S
# 888       0.0     3.0  female  28.0    1.0    2.0  23.4500        S
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q
# 891       NaN     NaN     NaN  28.0    NaN    NaN      NaN        S
#
# [892 rows x 8 columns]

# %% [markdown]
# #### This row has so many missing value that's why we delete it

# %%
df = df.drop(index=891)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0     3.0    male  22.0    1.0    0.0   7.2500        S
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833        C
# 2         1.0     3.0  female  26.0    0.0    0.0   7.9250        S
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S
# 4         0.0     3.0    male  35.0    0.0    0.0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0     2.0    male  27.0    0.0    0.0  13.0000        S
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S
# 888       0.0     3.0  female  28.0    1.0    2.0  23.4500        S
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# #### Doing almost same thing for test dataset

# %%
df1=pd.read_csv("test.csv")
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1['Embarked'] = df1['Embarked'].fillna(df1['Embarked'].mode()[0])
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2= pd.read_csv("gender_submission.csv")
df2
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### We joing the two datasets to get sarvived data for test dataset

# %%
df3 = pd.merge(df1, df2, on='PassengerId', how='inner')
df3
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df3 = df3.drop(["PassengerId", "Name" , "Ticket","Cabin" ], axis=1)
df3
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Survived
# 0         3    male  34.5      0      0    7.8292        Q         0
# 1         3  female  47.0      1      0    7.0000        S         1
# 2         2    male  62.0      0      0    9.6875        Q         0
# 3         3    male  27.0      0      0    8.6625        S         0
# 4         3  female  22.0      1      1   12.2875        S         1
# ..      ...     ...   ...    ...    ...       ...      ...       ...
# 413       3    male   NaN      0      0    8.0500        S         0
# 414       1  female  39.0      0      0  108.9000        C         1
# 415       3    male  38.5      0      0    7.2500        S         0
# 416       3    male   NaN      0      0    8.0500        S         0
# 417       3    male   NaN      1      1   22.3583        C         0
#
# [418 rows x 8 columns]

# %%
df3.isnull().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# Survived     0
# dtype: int64

# %%
df3['Age'].fillna(df3['Age'].median(), inplace=True)
df3['Fare'].fillna(df3['Fare'].median(), inplace=True)
df3.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Survived    0
# dtype: int64

# %%
df.to_csv('Cleaned_Train.csv', index=False)
df3.to_csv('Cleaned_Test.csv', index=False)
